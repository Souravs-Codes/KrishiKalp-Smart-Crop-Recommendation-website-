# %% [markdown]
# # KrishiKalp - Soil Health Data Exploration
#
# ### Objective
# The goal of this notebook is to understand the Soil Health Card dataset, analyze its structure, identify missing values, explore nutrient information, and prepare the data for building a Regional Soil Intelligence Database.
#
# Author: Sourav Mukherjee

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)

# %%
import os

print(os.getcwd())
# Out:
# d:\VS CODE SAVES\NTCC\KrishKalp\KrishiKalp-Smart-Crop-Recommendation-website-\notebooks

# %%
df = pd.read_csv("../data/raw/soil-nutrient-analysis.csv")
df.head()
# Out:
#         id     year   state_name  state_code      district_name  \
# 0  3107023  2023-24  Uttarakhand           5  Udham Singh Nagar
# 1  3107024  2023-24  Uttarakhand           5  Udham Singh Nagar
# 2  3107025  2023-24  Uttarakhand           5  Udham Singh Nagar
# 3  3107026  2023-24  Uttarakhand           5  Udham Singh Nagar
# 4  3107027  2023-24  Uttarakhand           5  Udham Singh Nagar
#
#    district_code block_name  block_code village_name  village_code  \
# 0             56   Rudrapur         439        Malsi         55943
# 1             56   Rudrapur         439        Malsi         55943
# 2             56   Rudrapur         439        Malsi         55943
# 3             56   Rudrapur         439        Malsi         55943
# 4             56   Rudrapur         439        Malsi         55943
#
#   nutrient_type nutrient_name nutrient_level  value
# 0         Micro        Copper      Deficient      0
# 1         Micro        Copper     Sufficient     85
# ...

# %%
print("Rows :", df.shape[0])
print("Columns :", df.shape[1])
# Out:
# Rows : 10853209
# Columns : 14

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10853209 entries, 0 to 10853208
# Data columns (total 14 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   id              int64
#  1   year            str
#  2   state_name      str
#  3   state_code      int64
#  4   district_name   str
#  5   district_code   int64
#  6   block_name      str
#  7   block_code      int64
#  8   village_name    str
#  9   village_code    int64
#  10  nutrient_type   str
#  11  nutrient_name   str
#  12  nutrient_level  str
#  13  value           int64
# dtypes: int64(6), str(8)
# memory usage: 1.1 GB

# %%
df.isnull().sum()
# Out:
# id                0
# year              0
# state_name        0
# state_code        0
# district_name     0
# district_code     0
# block_name        0
# block_code        0
# village_name      0
# village_code      0
# nutrient_type     0
# nutrient_name     0
# nutrient_level    0
# value             0
# dtype: int64

# %%
print("Duplicate Rows:", df.duplicated().sum())
# Out:
# Duplicate Rows: 0

# %% [markdown]
# ## Available nutrients

# %%
sorted(df["nutrient_name"].unique())
# Out:
# ['Boron',
#  'Copper',
#  'Electrical Conductivity',
#  'Iron',
#  'Manganese',
#  'Nitrogen',
#  'Organic Carbon',
#  'Phosphorus',
#  'Potassium',
#  'Soil Ph',
#  'Sulphur',
#  'Zinc']

# %% [markdown]
# ## Nutrient categories

# %%
df["nutrient_type"].unique()
# Out:
# <StringArray>
# ['Micro', 'Macro']
# Length: 2, dtype: str

# %% [markdown]
# ## Geographic coverage

# %%
print("States   :", df["state_name"].nunique())
print("Districts:", df["district_name"].nunique())
print("Blocks   :", df["block_name"].nunique())
print("Villages :", df["village_name"].nunique())
# Out:
# States   : 32
# Districts: 735
# Blocks   : 6289
# Villages : 210725

# %%
df["nutrient_level"].value_counts()
# Out:
# nutrient_level
# Sufficient    2245649
# Deficient     2245370
# Medium        1497086
# High          1496985
# Low           1496980
# Non Saline     374293
# Neutral        374292
# Acidic         374208
# Saline         374182
# Alkaline       374164
# Name: count, dtype: int64
