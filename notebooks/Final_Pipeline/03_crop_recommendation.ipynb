# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd

df = pd.read_csv("../../data/processed/master_dataset.csv")

print(df.shape)

df.head()
# Out:
# (449505, 25)
#        state_name district_name  year  season          crop      area  \
# 0  ANDHRA PRADESH      CHITTOOR  1997  Kharif     Arhar/Tur    6100.0
# 1  ANDHRA PRADESH      CHITTOOR  1997  Kharif         Bajra    1700.0
# 2  ANDHRA PRADESH      CHITTOOR  1997  Kharif  Dry chillies     600.0
# 3  ANDHRA PRADESH      CHITTOOR  1997  Kharif     Groundnut  234900.0
# 4  ANDHRA PRADESH      CHITTOOR  1997  Kharif    Horse-gram    3100.0
#
#    production     yield      Boron   Copper  ...  Phosphorus  Potassium  \
# 0       900.0  0.147541  12.343402  12.2969  ...    8.231055   8.231055
# 1      1900.0  1.117647  12.343402  12.2969  ...    8.231055   8.231055
# 2       800.0  1.333333  12.343402  12.2969  ...    8.231055   8.231055
# 3    144200.0  0.613878  12.343402  12.2969  ...    8.231055   8.231055
# 4      2000.0  0.645161  12.343402  12.2969  ...    8.231055   8.231055
#
#     Soil Ph    Sulphur       Zinc  temperature  rainfall   humidity  \
# ...

# %%
recommendation_df = (
    df.groupby(
        [
            "state_name",
            "district_name",
            "year",
            "season",
            "Boron",
            "Copper",
            "Electrical Conductivity",
            "Iron",
            "Manganese",
            "Nitrogen",
            "Organic Carbon",
            "Phosphorus",
            "Potassium",
            "Soil Ph",
            "Sulphur",
            "Zinc",
            "temperature",
            "rainfall",
            "humidity",
            "wind_speed",
            "solar_radiation",
        ]
    )
    .agg(
        {
            "crop": lambda x: list(sorted(set(x)))
        }
    )
    .reset_index()
)

# %%
print(recommendation_df.shape)

recommendation_df.head()
# Out:
# (39268, 22)
#        state_name district_name  year      season      Boron   Copper  \
# 0  ANDHRA PRADESH      CHITTOOR  1997      Kharif  12.343402  12.2969
# 1  ANDHRA PRADESH      CHITTOOR  1997        Rabi  12.343402  12.2969
# 2  ANDHRA PRADESH      CHITTOOR  1998      Kharif  12.343402  12.2969
# 3  ANDHRA PRADESH      CHITTOOR  1998        Rabi  12.343402  12.2969
# 4  ANDHRA PRADESH      CHITTOOR  1998  Whole Year  12.343402  12.2969
#
#    Electrical Conductivity       Iron  Manganese  Nitrogen  ...  Potassium  \
# 0                12.337043  12.336248  12.333863   8.22602  ...   8.231055
# 1                12.337043  12.336248  12.333863   8.22602  ...   8.231055
# 2                12.337043  12.336248  12.333863   8.22602  ...   8.231055
# 3                12.337043  12.336248  12.333863   8.22602  ...   8.231055
# 4                12.337043  12.336248  12.333863   8.22602  ...   8.231055
#
#     Soil Ph    Sulphur       Zinc  temperature  rainfall   humidity  \
# ...

# %%
recommendation_df["num_crops"] = recommendation_df["crop"].apply(len)

recommendation_df["num_crops"].describe()
# Out:
# count    39268.000000
# mean         7.047061
# std          5.131894
# min          1.000000
# 25%          2.000000
# 50%          6.000000
# 75%         10.000000
# max         49.000000
# Name: num_crops, dtype: float64

# %%
recommendation_df.loc[recommendation_df["num_crops"].idxmax()]
# Out:
# state_name                                                        TAMIL NADU
# district_name                                                       DINDIGUL
# year                                                                    2002
# season                                                            Whole Year
# Boron                                                              28.687943
# Copper                                                             28.702128
# Electrical Conductivity                                            28.515957
# Iron                                                               28.730496
# Manganese                                                           28.73227
# Nitrogen                                                           19.085106
# Organic Carbon                                                     19.061466
# Phosphorus                                                         19.096927
# ...

# %%
recommendation_df.loc[
    recommendation_df["num_crops"].idxmax(),
    "crop"
]
# Out:
# ['Apple',
#  'Banana',
#  'Beans & Mutter(Vegetable)',
#  'Beet Root',
#  'Bhindi',
#  'Bitter Gourd',
#  'Bottle Gourd',
#  'Brinjal',
#  'Cabbage',
#  'Carrot',
#  'Cashewnut',
#  'Cauliflower',
#  'Citrus Fruit',
#  'Coconut',
#  'Coriander',
#  'Cucumber',
#  'Drum Stick',
#  'Dry chillies',
#  'Dry ginger',
#  'Garlic',
#  'Ginger',
#  'Grapes',
#  'Jack Fruit',
#  'Lab-Lab',
#  'Mango',
#  'Onion',
#  'Orange',
#  'Other Citrus Fruit',
#  'Other Fresh Fruits',
#  'Other Vegetables',
#  'Papaya',
#  'Peach',
#  'Pear',
#  'Pineapple',
#  'Plums',
#  'Pome Fruit',
#  'Pome Granet',
#  'Potato',
#  'Pump Kin',
#  'Redish',
#  'Snak Guard',
#  'Sugarcane',
#  'Sweet potato',
#  'Tapioca',
#  'Tobacco',
#  'Tomato',
#  'Turmeric',
#  'Turnip',
#  'Water Melon']

# %%
from collections import Counter

crop_counter = Counter()

for crops in recommendation_df["crop"]:
    crop_counter.update(crops)

crop_frequency = (
    pd.DataFrame(
        crop_counter.items(),
        columns=["crop", "count"]
    )
    .sort_values("count", ascending=False)
    .reset_index(drop=True)
)

crop_frequency.head(20)
# Out:
#                      crop  count
# 0                    Rice  16401
# 1                   Maize  15643
# 2       Moong(Green Gram)  11579
# 3                    Urad  11061
# 4                 Sesamum  10000
# 5               Groundnut   9456
# 6                   Wheat   8987
# 7               Sugarcane   8785
# 8       Rapeseed &Mustard   8716
# 9               Arhar/Tur   8503
# 10                  Onion   8411
# 11                 Potato   8380
# 12                   Gram   8173
# 13                  Jowar   7522
# 14           Dry chillies   6780
# 15                  Bajra   6333
# 16  Peas & beans (Pulses)   5785
# 17          Small millets   5402
# 18              Sunflower   5180
# 19                 Masoor   5161

# %%
crop_frequency.head(20)
# Out:
#                      crop  count
# 0                    Rice  16401
# 1                   Maize  15643
# 2       Moong(Green Gram)  11579
# 3                    Urad  11061
# 4                 Sesamum  10000
# 5               Groundnut   9456
# 6                   Wheat   8987
# 7               Sugarcane   8785
# 8       Rapeseed &Mustard   8716
# 9               Arhar/Tur   8503
# 10                  Onion   8411
# 11                 Potato   8380
# 12                   Gram   8173
# 13                  Jowar   7522
# 14           Dry chillies   6780
# 15                  Bajra   6333
# 16  Peas & beans (Pulses)   5785
# 17          Small millets   5402
# 18              Sunflower   5180
# 19                 Masoor   5161

# %%
len(crop_frequency)
# Out:
# 126

# %%
environment_cols = [col for col in recommendation_no_year.columns if col not in ["crop", "num_crops"]]

print(recommendation_no_year.duplicated(subset=environment_cols).sum())
# Out:
# 0

# %%
recommendation_df = recommendation_df.drop(columns=["year"])

# %%
print(recommendation_df.columns.tolist())
# Out:
# ['state_name', 'district_name', 'season', 'Boron', 'Copper', 'Electrical Conductivity', 'Iron', 'Manganese', 'Nitrogen', 'Organic Carbon', 'Phosphorus', 'Potassium', 'Soil Ph', 'Sulphur', 'Zinc', 'temperature', 'rainfall', 'humidity', 'wind_speed', 'solar_radiation', 'crop', 'num_crops']

# %%
X = recommendation_df.drop(columns=["crop", "num_crops"])
y = recommendation_df["crop"]

print(X.shape)
print(y.shape)
# Out:
# (39268, 20)
# (39268,)

# %%
from sklearn.preprocessing import MultiLabelBinarizer

mlb = MultiLabelBinarizer()

y_encoded = mlb.fit_transform(y)

print(y_encoded.shape)
# Out:
# (39268, 126)

# %%
print(mlb.classes_)
# Out:
# ['Apple' 'Arcanut (Processed)' 'Arecanut' 'Arhar/Tur' 'Ash Gourd'
#  'Atcanut (Raw)' 'Bajra' 'Banana' 'Barley' 'Bean'
#  'Beans & Mutter(Vegetable)' 'Beet Root' 'Ber' 'Bhindi' 'Bitter Gourd'
#  'Black pepper' 'Blackgram' 'Bottle Gourd' 'Brinjal' 'Cabbage' 'Cardamom'
#  'Carrot' 'Cashewnut' 'Cashewnut Processed' 'Cashewnut Raw' 'Castor seed'
#  'Cauliflower' 'Citrus Fruit' 'Coconut' 'Coffee' 'Colocosia'
#  'Cond-spcs other' 'Coriander' 'Cotton(lint)' 'Cowpea(Lobia)' 'Cucumber'
#  'Drum Stick' 'Dry chillies' 'Dry ginger' 'Garlic' 'Ginger' 'Gram'
#  'Grapes' 'Groundnut' 'Guar seed' 'Horse-gram' 'Jack Fruit' 'Jobster'
#  'Jowar' 'Jute' 'Jute & mesta' 'Kapas' 'Khesari' 'Korra' 'Lab-Lab' 'Lemon'
#  'Lentil' 'Linseed' 'Litchi' 'Maize' 'Mango' 'Masoor' 'Mesta'
#  'Moong(Green Gram)' 'Moth' 'Niger seed' 'Oilseeds total' 'Onion' 'Orange'
#  'Other  Rabi pulses' 'Other Cereals' 'Other Cereals & Millets'
#  'Other Citrus Fruit' 'Other Fresh Fruits' 'Other Kharif pulses'
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y_encoded,
    test_size=0.2,
    random_state=42
)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (31414, 20)
# (7854, 20)
# (31414, 126)
# (7854, 126)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer

# %%
categorical_features = X_train.select_dtypes(include=["object"]).columns.tolist()
numerical_features = X_train.select_dtypes(exclude=["object"]).columns.tolist()

print("Categorical:", categorical_features)
print("\nNumerical:", numerical_features)
# Out:
# Categorical: ['state_name', 'district_name', 'season']
#
# Numerical: ['Boron', 'Copper', 'Electrical Conductivity', 'Iron', 'Manganese', 'Nitrogen', 'Organic Carbon', 'Phosphorus', 'Potassium', 'Soil Ph', 'Sulphur', 'Zinc', 'temperature', 'rainfall', 'humidity', 'wind_speed', 'solar_radiation']

# %%
preprocessor = ColumnTransformer(
    transformers=[
        (
            "cat",
            Pipeline([
                ("imputer", SimpleImputer(strategy="most_frequent")),
                ("encoder", OneHotEncoder(handle_unknown="ignore"))
            ]),
            categorical_features
        ),
        (
            "num",
            Pipeline([
                ("imputer", SimpleImputer(strategy="median"))
            ]),
            numerical_features
        )
    ]
)

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier(random_state=42)

# %%
from sklearn.multioutput import MultiOutputClassifier

dt_model = MultiOutputClassifier(
    DecisionTreeClassifier(random_state=42)
)

# %%
dt_model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 dt_model.fit(X_train, y_train)
#
# File d:\VS CODE SAVES\NTCC\KrishKalp\KrishiKalp-Smart-Crop-Recommendation-website-\venv\Lib\site-packages\sklearn\multioutput.py:543, in MultiOutputClassifier.fit(self, X, Y, sample_weight, **fit_params)
#     517 def fit(self, X, Y, sample_weight=None, **fit_params):
#     518     """Fit the model to data matrix X and targets Y.
#     519
#     520     Parameters
#    (...)    541         Returns a fitted instance.
#     542     """
# --> 543     super().fit(X, Y, sample_weight=sample_weight, **fit_params)
#     544     self.classes_ = [estimator.classes_ for estimator in self.estimators_]
#     545     return self
#
# ...

# %%
from sklearn.pipeline import Pipeline

dt_pipeline = Pipeline([
    ("preprocessor", preprocessor),
    ("classifier", MultiOutputClassifier(
        DecisionTreeClassifier(random_state=42)
    ))
])

# %%
dt_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['state_name',
#                                                    'district_name', 'season']),
#                                                  ('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median'))]),
#                                                   ['Boron', 'Copper',
# ...

# %%
from sklearn.metrics import hamming_loss

y_pred = dt_pipeline.predict(X_test)

print("Hamming Loss:", hamming_loss(y_test, y_pred))
# Out:
# Hamming Loss: 0.021630874572051043

# %%
from sklearn.metrics import f1_score

print("Micro F1:", f1_score(y_test, y_pred, average="micro"))
# Out:
# Micro F1: 0.8074376596739952

# %%
print("Macro F1:", f1_score(y_test, y_pred, average="macro"))
# Out:
# Macro F1: 0.500135125432248

# %%
results = pd.DataFrame({
    "Model": ["Decision Tree"],
    "Hamming Loss": [hamming_loss(y_test, y_pred)],
    "Micro F1": [f1_score(y_test, y_pred, average="micro")],
    "Macro F1": [f1_score(y_test, y_pred, average="macro")]
})

results
# Out:
#            Model  Hamming Loss  Micro F1  Macro F1
# 0  Decision Tree      0.021631  0.807438  0.500135

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.pipeline import Pipeline
from sklearn.multioutput import MultiOutputClassifier

rf_pipeline = Pipeline([
    ("preprocessor", preprocessor),
    ("classifier", MultiOutputClassifier(
        RandomForestClassifier(
            n_estimators=100,
            random_state=42,
            n_jobs=-1
        )
    ))
])

# %%
rf_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['state_name',
#                                                    'district_name', 'season']),
#                                                  ('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median'))]),
#                                                   ['Boron', 'Copper',
# ...

# %%
from sklearn.metrics import hamming_loss, f1_score

y_pred_rf = rf_pipeline.predict(X_test)

print("Hamming Loss:", hamming_loss(y_test, y_pred_rf))
print("Micro F1:", f1_score(y_test, y_pred_rf, average="micro"))
print("Macro F1:", f1_score(y_test, y_pred_rf, average="macro"))
# Out:
# Hamming Loss: 0.01945121482936609
# Micro F1: 0.8171898000854741
# Macro F1: 0.34302658217001647

# %%
results.loc[len(results)] = [
    "Random Forest",
    hamming_loss(y_test, y_pred_rf),
    f1_score(y_test, y_pred_rf, average="micro"),
    f1_score(y_test, y_pred_rf, average="macro")
]

results
# Out:
#            Model  Hamming Loss  Micro F1  Macro F1
# 0  Decision Tree      0.021631  0.807438  0.500135
# 1  Random Forest      0.019451  0.817190  0.343027

# %%
from xgboost import XGBClassifier

# %%
xgb_pipeline = Pipeline([
    ("preprocessor", preprocessor),
    ("classifier", MultiOutputClassifier(
        XGBClassifier(
            n_estimators=100,
            max_depth=6,
            learning_rate=0.1,
            random_state=42,
            n_jobs=-1,
            eval_metric="logloss"
        )
    ))
])

# %%
xgb_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['state_name',
#                                                    'district_name', 'season']),
#                                                  ('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median'))]),
#                                                   ['Boron', 'Copper',
# ...

# %%
y_pred_xgb = xgb_pipeline.predict(X_test)

print("Hamming Loss:", hamming_loss(y_test, y_pred_xgb))
print("Micro F1:", f1_score(y_test, y_pred_xgb, average="micro"))
print("Macro F1:", f1_score(y_test, y_pred_xgb, average="macro"))
# Out:
# Hamming Loss: 0.019400689568756797
# Micro F1: 0.8218768845386649
# Macro F1: 0.45208845991649294

# %%
results.loc[len(results)] = [
    "XGBoost",
    hamming_loss(y_test, y_pred_xgb),
    f1_score(y_test, y_pred_xgb, average="micro"),
    f1_score(y_test, y_pred_xgb, average="macro")
]

results
# Out:
#            Model  Hamming Loss  Micro F1  Macro F1
# 0  Decision Tree      0.021631  0.807438  0.500135
# 1  Random Forest      0.019451  0.817190  0.343027
# 2        XGBoost      0.019401  0.821877  0.452088

# %%
from lightgbm import LGBMClassifier

# %%
lgbm_pipeline = Pipeline([
    ("preprocessor", preprocessor),
    ("classifier", MultiOutputClassifier(
        LGBMClassifier(
            n_estimators=100,
            learning_rate=0.1,
            random_state=42,
            n_jobs=-1,
            verbose=-1
        )
    ))
])

# %%
lgbm_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['state_name',
#                                                    'district_name', 'season']),
#                                                  ('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median'))]),
#                                                   ['Boron', 'Copper',
# ...

# %%
y_pred_lgbm = lgbm_pipeline.predict(X_test)

print("Hamming Loss:", hamming_loss(y_test, y_pred_lgbm))
print("Micro F1:", f1_score(y_test, y_pred_lgbm, average="micro"))
print("Macro F1:", f1_score(y_test, y_pred_lgbm, average="macro"))
# Out:
# Hamming Loss: 0.01824568211122833
# Micro F1: 0.8353456137151195
# Macro F1: 0.44660053190739407

# %%
results.loc[len(results)] = [
    "LightGBM",
    hamming_loss(y_test, y_pred_lgbm),
    f1_score(y_test, y_pred_lgbm, average="micro"),
    f1_score(y_test, y_pred_lgbm, average="macro")
]

results
# Out:
#            Model  Hamming Loss  Micro F1  Macro F1
# 0  Decision Tree      0.021631  0.807438  0.500135
# 1  Random Forest      0.019451  0.817190  0.343027
# 2        XGBoost      0.019401  0.821877  0.452088
# 3       LightGBM      0.018246  0.835346  0.446601

# %%
from catboost import CatBoostClassifier

# %%
cat_pipeline = Pipeline([
    ("preprocessor", preprocessor),
    ("classifier", MultiOutputClassifier(
        CatBoostClassifier(
            iterations=100,
            learning_rate=0.1,
            depth=6,
            random_seed=42,
            verbose=0
        )
    ))
])

# %%
cat_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['state_name',
#                                                    'district_name', 'season']),
#                                                  ('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median'))]),
#                                                   ['Boron', 'Copper',
# ...

# %%
y_pred_cat = cat_pipeline.predict(X_test)

print("Hamming Loss:", hamming_loss(y_test, y_pred_cat))
print("Micro F1:", f1_score(y_test, y_pred_cat, average="micro"))
print("Macro F1:", f1_score(y_test, y_pred_cat, average="macro"))
# Out:
# Hamming Loss: 0.019715967194958793
# Micro F1: 0.8179621388119163
# Macro F1: 0.4462699439090651

# %%
results.loc[len(results)] = [
    "CatBoost",
    hamming_loss(y_test, y_pred_cat),
    f1_score(y_test, y_pred_cat, average="micro"),
    f1_score(y_test, y_pred_cat, average="macro")
]

results
# Out:
#            Model  Hamming Loss  Micro F1  Macro F1
# 0  Decision Tree      0.021631  0.807438  0.500135
# 1  Random Forest      0.019451  0.817190  0.343027
# 2        XGBoost      0.019401  0.821877  0.452088
# 3       LightGBM      0.018246  0.835346  0.446601
# 4       CatBoost      0.019716  0.817962  0.446270

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn_pipeline = Pipeline([
    ("preprocessor", preprocessor),
    ("classifier", MultiOutputClassifier(
        KNeighborsClassifier(
            n_neighbors=5,
            weights="uniform"
        )
    ))
])

# %%
knn_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['state_name',
#                                                    'district_name', 'season']),
#                                                  ('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median'))]),
#                                                   ['Boron', 'Copper',
# ...

# %%
y_pred_knn = knn_pipeline.predict(X_test)

print("Hamming Loss:", hamming_loss(y_test, y_pred_knn))
print("Micro F1:", f1_score(y_test, y_pred_knn, average="micro"))
print("Macro F1:", f1_score(y_test, y_pred_knn, average="macro"))
# Out:
# Hamming Loss: 0.05880534031794536
# Micro F1: 0.18525466916809005
# Macro F1: 0.0539785111920831

# %%
results.loc[len(results)] = [
    "KNN",
    hamming_loss(y_test, y_pred_knn),
    f1_score(y_test, y_pred_knn, average="micro"),
    f1_score(y_test, y_pred_knn, average="macro")
]

results
# Out:
#            Model  Hamming Loss  Micro F1  Macro F1
# 0  Decision Tree      0.021631  0.807438  0.500135
# 1  Random Forest      0.019451  0.817190  0.343027
# 2        XGBoost      0.019401  0.821877  0.452088
# 3       LightGBM      0.018246  0.835346  0.446601
# 4       CatBoost      0.019716  0.817962  0.446270
# 5            KNN      0.058805  0.185255  0.053979

# %%
from sklearn.linear_model import LogisticRegression

# %%
logreg_pipeline = Pipeline([
    ("preprocessor", preprocessor),
    ("classifier", MultiOutputClassifier(
        LogisticRegression(
            max_iter=1000,
            random_state=42,
            n_jobs=-1
        )
    ))
])

# %%
logreg_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['state_name',
#                                                    'district_name', 'season']),
#                                                  ('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median'))]),
#                                                   ['Boron', 'Copper',
# ...

# %%
y_pred_logreg = logreg_pipeline.predict(X_test)

print("Hamming Loss:", hamming_loss(y_test, y_pred_logreg))
print("Micro F1:", f1_score(y_test, y_pred_logreg, average="micro"))
print("Macro F1:", f1_score(y_test, y_pred_logreg, average="macro"))
# Out:
# Hamming Loss: 0.030804240888274503
# Micro F1: 0.705394591878153
# Macro F1: 0.28830053100305275

# %%
results.loc[len(results)] = [
    "Logistic Regression",
    hamming_loss(y_test, y_pred_logreg),
    f1_score(y_test, y_pred_logreg, average="micro"),
    f1_score(y_test, y_pred_logreg, average="macro")
]

results
# Out:
#                  Model  Hamming Loss  Micro F1  Macro F1
# 0        Decision Tree      0.021631  0.807438  0.500135
# 1        Random Forest      0.019451  0.817190  0.343027
# 2              XGBoost      0.019401  0.821877  0.452088
# 3             LightGBM      0.018246  0.835346  0.446601
# 4             CatBoost      0.019716  0.817962  0.446270
# 5                  KNN      0.058805  0.185255  0.053979
# 6  Logistic Regression      0.030804  0.705395  0.288301

# %%
from sklearn.svm import LinearSVC

# %%
svm_pipeline = Pipeline([
    ("preprocessor", preprocessor),
    ("classifier", MultiOutputClassifier(
        LinearSVC(
            random_state=42,
            max_iter=5000
        )
    ))
])

# %%
svm_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['state_name',
#                                                    'district_name', 'season']),
#                                                  ('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median'))]),
#                                                   ['Boron', 'Copper',
# ...

# %%
y_pred_svm = svm_pipeline.predict(X_test)

print("Hamming Loss:", hamming_loss(y_test, y_pred_svm))
print("Micro F1:", f1_score(y_test, y_pred_svm, average="micro"))
print("Macro F1:", f1_score(y_test, y_pred_svm, average="macro"))
# Out:
# Hamming Loss: 0.026700579221587625
# Micro F1: 0.7487949802728526
# Macro F1: 0.3168040948590367

# %%
results.loc[len(results)] = [
    "Linear SVM",
    hamming_loss(y_test, y_pred_svm),
    f1_score(y_test, y_pred_svm, average="micro"),
    f1_score(y_test, y_pred_svm, average="macro")
]

results
# Out:
#                  Model  Hamming Loss  Micro F1  Macro F1
# 0        Decision Tree      0.021631  0.807438  0.500135
# 1        Random Forest      0.019451  0.817190  0.343027
# 2              XGBoost      0.019401  0.821877  0.452088
# 3             LightGBM      0.018246  0.835346  0.446601
# 4             CatBoost      0.019716  0.817962  0.446270
# 5                  KNN      0.058805  0.185255  0.053979
# 6  Logistic Regression      0.030804  0.705395  0.288301
# 7           Linear SVM      0.026701  0.748795  0.316804

# %%
lgbm_pipeline_tuned = Pipeline([
    ("preprocessor", preprocessor),
    ("classifier", MultiOutputClassifier(
        LGBMClassifier(
            n_estimators=300,
            learning_rate=0.05,
            num_leaves=31,
            random_state=42,
            n_jobs=-1,
            verbose=-1
        )
    ))
])

# %%
lgbm_pipeline_tuned.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['state_name',
#                                                    'district_name', 'season']),
#                                                  ('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median'))]),
#                                                   ['Boron', 'Copper',
# ...

# %%
y_pred_lgbm_tuned = lgbm_pipeline_tuned.predict(X_test)

print("Hamming Loss:", hamming_loss(y_test, y_pred_lgbm_tuned))
print("Micro F1:", f1_score(y_test, y_pred_lgbm_tuned, average="micro"))
print("Macro F1:", f1_score(y_test, y_pred_lgbm_tuned, average="macro"))
# Out:
# Hamming Loss: 0.01722102982607184
# Micro F1: 0.8440519765739385
# Macro F1: 0.4767077716157656

# %%
results.loc[len(results)] = [
    "LightGBM (Tuned)",
    hamming_loss(y_test, y_pred_lgbm_tuned),
    f1_score(y_test, y_pred_lgbm_tuned, average="micro"),
    f1_score(y_test, y_pred_lgbm_tuned, average="macro")
]

results
# Out:
#                  Model  Hamming Loss  Micro F1  Macro F1
# 0        Decision Tree      0.021631  0.807438  0.500135
# 1        Random Forest      0.019451  0.817190  0.343027
# 2              XGBoost      0.019401  0.821877  0.452088
# 3             LightGBM      0.018246  0.835346  0.446601
# 4             CatBoost      0.019716  0.817962  0.446270
# 5                  KNN      0.058805  0.185255  0.053979
# 6  Logistic Regression      0.030804  0.705395  0.288301
# 7           Linear SVM      0.026701  0.748795  0.316804
# 8     LightGBM (Tuned)      0.017221  0.844052  0.476708

# %%
from sklearn.model_selection import KFold, cross_val_score

# %%
kf = KFold(
    n_splits=5,
    shuffle=True,
    random_state=42
)

# %%
from sklearn.model_selection import cross_validate
from sklearn.metrics import make_scorer, f1_score

# %%
micro_f1_scorer = make_scorer(
    f1_score,
    average="micro"
)

# %%
cv_results = cross_validate(
    lgbm_pipeline_tuned,
    X,
    y_encoded,
    cv=kf,
    scoring={"micro_f1": micro_f1_scorer},
    n_jobs=-1
)

print("Cross-validation Micro F1 scores:", cv_results["test_micro_f1"])
print("Mean Micro F1:", cv_results["test_micro_f1"].mean())
print("Std Dev:", cv_results["test_micro_f1"].std())
# Out:
# Cross-validation Micro F1 scores: [0.84380203 0.84491313 0.84526795 0.84341063 0.84323963]
# Mean Micro F1: 0.8441266734929573
# Std Dev: 0.0008155946890017872

# %%
import joblib

joblib.dump(lgbm_pipeline_tuned, "lightgbm_tuned_crop_recommender.pkl")
# Out:
# ['lightgbm_tuned_crop_recommender.pkl']

# %%
joblib.dump(mlb, "multilabel_binarizer.pkl")
# Out:
# ['multilabel_binarizer.pkl']

# %%
loaded_model = joblib.load("lightgbm_tuned_crop_recommender.pkl")
loaded_mlb = joblib.load("multilabel_binarizer.pkl")

# %%
sample_input = X.iloc[[0]]

prediction = loaded_model.predict(sample_input)

# %%
recommended_crops = loaded_mlb.inverse_transform(prediction)

print("Recommended Crops:")
print(recommended_crops[0])
# Out:
# Recommended Crops:
# ('Arhar/Tur', 'Bajra', 'Castor seed', 'Cotton(lint)', 'Dry chillies', 'Groundnut', 'Horse-gram', 'Jowar', 'Maize', 'Moong(Green Gram)', 'Onion', 'Other Kharif pulses', 'Ragi', 'Rice', 'Samai', 'Sesamum', 'Small millets', 'Sunflower', 'Urad')

# %%
print("Actual Crops:")
print(y.iloc[0])

print("\nPredicted Crops:")
print(recommended_crops[0])
# Out:
# Actual Crops:
# ['Arhar/Tur', 'Bajra', 'Dry chillies', 'Groundnut', 'Horse-gram', 'Jowar', 'Maize', 'Moong(Green Gram)', 'Other Kharif pulses', 'Ragi', 'Rice', 'Samai', 'Sesamum', 'Sugarcane', 'Sunflower']
#
# Predicted Crops:
# ('Arhar/Tur', 'Bajra', 'Castor seed', 'Cotton(lint)', 'Dry chillies', 'Groundnut', 'Horse-gram', 'Jowar', 'Maize', 'Moong(Green Gram)', 'Onion', 'Other Kharif pulses', 'Ragi', 'Rice', 'Samai', 'Sesamum', 'Small millets', 'Sunflower', 'Urad')

# %%
def recommend_crops(input_df):
    prediction = loaded_model.predict(input_df)
    return loaded_mlb.inverse_transform(prediction)[0]

# %%
recommend_crops(sample_input)
# Out:
# ('Arhar/Tur',
#  'Bajra',
#  'Castor seed',
#  'Cotton(lint)',
#  'Dry chillies',
#  'Groundnut',
#  'Horse-gram',
#  'Jowar',
#  'Maize',
#  'Moong(Green Gram)',
#  'Onion',
#  'Other Kharif pulses',
#  'Ragi',
#  'Rice',
#  'Samai',
#  'Sesamum',
#  'Small millets',
#  'Sunflower',
#  'Urad')

# %%
print(X.columns.tolist())
# Out:
# ['state_name', 'district_name', 'season', 'Boron', 'Copper', 'Electrical Conductivity', 'Iron', 'Manganese', 'Nitrogen', 'Organic Carbon', 'Phosphorus', 'Potassium', 'Soil Ph', 'Sulphur', 'Zinc', 'temperature', 'rainfall', 'humidity', 'wind_speed', 'solar_radiation']
